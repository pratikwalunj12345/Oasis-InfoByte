# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car = pd.read_csv('raw.githubusercontent.com_amankharwal_Website-data_master_CarPrice.csv')
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(car.corr())
# Out:
# <AxesSubplot:>

# %%
print(car['carlength'].corr(car['price']))
print(car['carwidth'].corr(car['price']))
print(car['curbweight'].corr(car['price']))
print(car['enginesize'].corr(car['price']))
print(car['horsepower'].corr(car['price']))
# Out:
# 0.6829200156779629
# 0.7593252997415118
# 0.8353048793372965
# 0.8741448025245112
# 0.8081388225362212

# %%
df = car[['carlength','carwidth','curbweight','enginesize','horsepower','price']]
df.head()
# Out:
#    carlength  carwidth  curbweight  enginesize  horsepower    price
# 0      168.8      64.1        2548         130         111  13495.0
# 1      168.8      64.1        2548         130         111  16500.0
# 2      171.2      65.5        2823         152         154  16500.0
# 3      176.6      66.2        2337         109         102  13950.0
# 4      176.6      66.4        2824         136         115  17450.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   carlength   205 non-null    float64
#  1   carwidth    205 non-null    float64
#  2   curbweight  205 non-null    int64
#  3   enginesize  205 non-null    int64
#  4   horsepower  205 non-null    int64
#  5   price       205 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 9.7 KB

# %%
df.describe()
# Out:
#         carlength    carwidth   curbweight  enginesize  horsepower  \
# count  205.000000  205.000000   205.000000  205.000000  205.000000
# mean   174.049268   65.907805  2555.565854  126.907317  104.117073
# std     12.337289    2.145204   520.680204   41.642693   39.544167
# min    141.100000   60.300000  1488.000000   61.000000   48.000000
# 25%    166.300000   64.100000  2145.000000   97.000000   70.000000
# 50%    173.200000   65.500000  2414.000000  120.000000   95.000000
# 75%    183.100000   66.900000  2935.000000  141.000000  116.000000
# max    208.100000   72.300000  4066.000000  326.000000  288.000000
#
#               price
# count    205.000000
# mean   13276.710571
# std     7988.852332
# min     5118.000000
# 25%     7788.000000
# 50%    10295.000000
# 75%    16503.000000
# max    45400.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
sns.scatterplot(x = df['horsepower'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
#since car length and curbweight are highly correlated hence we take curbweight

df=df.drop(columns=['carlength'])
df.head()
# Out:
#    carwidth  curbweight  enginesize  horsepower    price
# 0      64.1        2548         130         111  13495.0
# 1      64.1        2548         130         111  16500.0
# 2      65.5        2823         152         154  16500.0
# 3      66.2        2337         109         102  13950.0
# 4      66.4        2824         136         115  17450.0

# %%
from sklearn.preprocessing import StandardScaler

# Extract the features to be normalized into a separate DataFrame
feature_normalize = df[['carwidth','curbweight','enginesize','horsepower']]

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the features
scaler.fit(feature_normalize)

# Transform the features using the scaler
normalized_features = scaler.transform(feature_normalize)

# Replace the original features in the DataFrame with the normalized ones
df[['carwidth','curbweight','enginesize','horsepower']] = normalized_features

# %%
df.head()
# Out:
#    carwidth  curbweight  enginesize  horsepower    price
# 0 -0.844782   -0.014566    0.074449    0.174483  13495.0
# 1 -0.844782   -0.014566    0.074449    0.174483  16500.0
# 2 -0.190566    0.514882    0.604046    1.264536  16500.0
# 3  0.136542   -0.420797   -0.431076   -0.053668  13950.0
# 4  0.230001    0.516807    0.218885    0.275883  17450.0

# %%
data = df.values
x = data[:,0:4]
y = data[:,4]

# %%
# train test split

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)

# %%
lr.predict([[0.174483,0.074449,-0.844782,-0.014566]])
# Out:
# array([10649.4011736])

# %%
from sklearn.metrics import r2_score
ac = r2_score(ytest,ypred)
ac
# Out:
# 0.7674164805829395
